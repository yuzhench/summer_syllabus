# %% [markdown]
# ## lecture from Youtube
#
# ### [lecture1 link:](https://www.youtube.com/watch?v=dhzLQfDBx2Q&list=PLgnQpQtFTOGQh_J16IMwDlji18SWQ2PZ6&index=7)
# ### [lecture2 link:](https://www.youtube.com/watch?v=ktRqKxddjJk&list=PLgnQpQtFTOGQh_J16IMwDlji18SWQ2PZ6&index=9)

# %% [markdown]
# ## Lecture 1
#
# 1. Assumption: When we know the correspondences for point pairs (**Point Cloud Registration with Known Date Association**).
#
#     - <img src="slides/icp1.png" width="50%" height="50%">
#     - <img src="slides/icp2.png" width="50%" height="50%">
#     - <img src="slides/icp3.png" width="50%" height="50%">
#     - <img src="slides/icp4.png" width="50%" height="50%">
#
#         - If we have the monocular images, then we don't have the scale information. Then we need the similarity transform.
#     - <img src="slides/icp5.png" width="50%" height="50%">
#
#         - Weight: How confident I am. If we have perfect correspondents, then all the weights are the same, which is equal to 1.
#     - <img src="slides/icp6.png" width="50%" height="50%">
#
#         - Under the perfect data association:
#             - Direct solution: It's not an iterative procedure where I need an initial guess; instead, I can come up with a rotation matrix and a translation vector that minimize the loss equation.
#             - Optimal solution: There is no better solution exists.
#     - <img src="slides/icp7.png" width="50%" height="50%">
#
#         - First: Calculate the mean of the points.
#         - H: Cross-correlation matrix.
#         - SVD: Decompose the matrix H into three parts.
#             - Then use the three new matrices we get to calculate the R --> rotation matrix.
#     - <img src="slides/icp8.png" width="50%" height="50%">
#
#         - Use the rotation matrix to calculate the transformation matrix.
#     - <img src="slides/icp9.png" width="50%" height="50%">
#
#         - Show all the solutions (not include the reason yet).
#     - <img src="slides/icp10.png" width="50%" height="50%">
#     - <img src="slides/icp11.png" width="50%" height="50%">
#     - <img src="slides/icp12.png" width="50%" height="50%">
#
#     ## Go back and start to explain why:
#
#     - <img src="slides/icp22.png" width="50%" height="50%">
#     - <img src="slides/icp23.png" width="50%" height="50%">
#
#         - Use the local coordination --> The origin point is the weighted mean mass of the y points set.
#         - -y0 and +y0 doesn't change the problem.
#     - <img src="slides/icp24.png" width="50%" height="50%">
#     - <img src="slides/icp25.png" width="50%" height="50%">
#     - <img src="slides/icp26.png" width="50%" height="50%">
#     - <img src="slides/icp27.png" width="50%" height="50%">
#     - <img src="slides/icp28.png" width="50%" height="50%">
#     - <img src="slides/icp29.png" width="50%" height="50%">
#
#     ### Solve w.r.t. x0
#     - <img src="slides/icp31.png" width="50%" height="50%">
#     - <img src="slides/icp33.png" width="50%" height="50%">
#     - <img src="slides/icp34.png" width="50%" height="50%">
#
#     ### Solve w.r.t. R
#     - <img src="slides/icp36.png" width="50%" height="50%">
#     - <img src="slides/icp37.png" width="50%" height="50%">
#     - <img src="slides/icp38.png" width="50%" height="50%">
#     - <img src="slides/icp39.png" width="50%" height="50%">
#     - <img src="slides/icp40.png" width="50%" height="50%">
#
#         - D is a diagonal matrix, so you can let D = D^1/2 * D^1/2.
#     - <img src="slides/icp41.png" width="50%" height="50%">
#     - <img src="slides/icp42.png" width="50%" height="50%">
#
#     ### old prove option slide:
#     - <img src="slides/icp43.png" width="50%" height="50%">
#     - <img src="slides/icp44.png" width="50%" height="50%">
#
#     ### when we will have the unique solution
#     - <img src="slides/icp45.png" width="50%" height="50%">
#
#     ### how to calculate the translation vector
#     - <img src="slides/icp46.png" width="50%" height="50%">
#     - <img src="slides/icp46.png" width="50%" height="50%">
#
#     ### conclusion:
#     - <img src="slides/icp49.png" width="50%" height="50%">

# %% [markdown]
# ## lecture 2
# 1. Assumption: When we don't know the correspondences for point pairs (**Point Cloud Registration with Known Date Association**).
#
#     - <img src="slides/icp50.png" width="50%" height="50%">
